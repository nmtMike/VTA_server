# %%
import pandas as pd
import sqlite3
from sqlalchemy import create_engine
from sqlalchemy.engine import URL

url_object = URL.create(
    "postgresql",
    username="lotus",
    password="lotus",
    host="localhost",
    port="5433",
    database="lotusdb")
engine = create_engine(url_object)

conn = sqlite3.connect(r"C:\Users\VTA-HAN\Desktop\VTA\VTA_RM.db")
c = conn.cursor()

# %%
engine

# %%
query = """
SELECT ori_station || des_station AS sector,
		STRFTIME('%Y-%m-%d', departure_date) AS departure_date,
		STRFTIME('%Y-%m-%d', book_date) AS book_date,
		COUNT(*) AS  counting
	FROM reservation
	WHERE departure_date >= '2023-01-06' AND departure_date <= '2023-02-06'
	GROUP BY ori_station, des_station, STRFTIME('%Y-%m-%d', departure_date), STRFTIME('%Y-%m-%d', book_date)
"""

df = pd.read_sql_query(query, conn)
df.to_csv('res_ve_tet.csv', index=False)

# %%
query = """
SELECT dep_station || arr_station AS sector,
		STRFTIME('%Y-%m-%d', Flight_Origin_Date_LT) AS departure_date,
		SUM(SUBSTRING(config, -3)*1) AS capacity,
		COUNT(*) AS frequency 
	FROM flown_aircraft_leg
	WHERE Flight_Origin_Date_LT >= '2023-01-06' AND Flight_Origin_Date_LT <= '2023-02-06'
	GROUP BY dep_station, arr_station, STRFTIME('%Y-%m-%d', Flight_Origin_Date_LT)
"""

df = pd.read_sql_query(query, conn)
df.to_csv('leg_tet.csv', index=False)

# %%
query = """
SELECT *
	FROM pax_transaction
	WHERE FLIGHT_NUM IN (136, 137)
"""

df = pd.read_sql_query(query, conn)
df.to_csv('pax_transaction_BKK.csv', index=False)

# %%
df = pd.read_csv(r'C:\Users\VTA-HAN\NMT\OneDrive\Viettravel Airline\Database\fact\reservation_segment_detail\Reservation Segment Detail Report - 20221101 - 20221130.csv',
                    dtype={'iata_num':str, 'confirmation_num':str, 'operating_flight_num':int}, index_col=None)

df['depart_date'] = pd.to_datetime(df['depart_date'])
df['reservation_book_date'] = pd.to_datetime(df['reservation_book_date'])
df['reservation_seg_book_date'] = pd.to_datetime(df['reservation_seg_book_date'])

# %%
df
# Out:
#         operating_flight_num depart_date from_airport to_airport  \
# 0                        780  2022-10-12          SGN        HAN
# 1                        780  2022-10-15          SGN        HAN
# 2                        780  2022-10-16          SGN        HAN
# 3                        787  2022-10-16          HAN        SGN
# 4                        787  2022-10-16          HAN        SGN
# ...                      ...         ...          ...        ...
# 171162                   673  2023-03-25          DAD        SGN
# 171163                   673  2023-03-25          DAD        SGN
# 171164                   673  2023-03-25          DAD        SGN
# 171165                   673  2023-03-25          DAD        SGN
# 171166                   673  2023-03-25          DAD        SGN
#
#        flight_status reservation_book_date reservation_seg_book_date  \
# 0             CLOSED   2022-10-03 16:11:45       2022-11-04 13:36:55
# 1             CLOSED   2022-10-03 16:15:48       2022-11-04 13:32:27
# 2             CLOSED   2022-10-03 14:08:06       2022-11-04 13:27:25
# 3             CLOSED   2022-10-03 16:11:45       2022-11-04 13:36:55
# 4             CLOSED   2022-10-03 16:15:48       2022-11-04 13:32:27
# ...              ...                   ...                       ...
# 171162          OPEN   2022-11-21 09:59:16       2022-11-21 09:59:16
# 171163          OPEN   2022-11-21 10:15:34       2022-11-21 10:15:34
# 171164          OPEN   2022-11-21 09:59:16       2022-11-21 09:59:16
# 171165          OPEN   2022-11-21 09:59:16       2022-11-21 09:59:16
# 171166          OPEN   2022-11-21 10:15:34       2022-11-21 10:15:34
#
#        reservation_segement_cancel_date confirmation_num  record_num  ...  \
# 0                                   NaN           14MGON           3  ...
# 1                                   NaN           V9KXPE           3  ...
# 2                                   NaN           BTFMTO           6  ...
# 3                                   NaN           14MGON           4  ...
# 4                                   NaN           V9KXPE           4  ...
# ...                                 ...              ...         ...  ...
# 171162                              NaN           JXXID5          60  ...
# 171163                              NaN           MONVL0           8  ...
# 171164                              NaN           JXXID5          12  ...
# 171165                              NaN           JXXID5          54  ...
# 171166                              NaN           MONVL0          12  ...
#
#        other_tax_amount fuel_tax_amount res_seg_status_descr  \
# 0              120000.0             0.0              BOARDED
# 1              132000.0             0.0              BOARDED
# 2              120000.0             0.0              BOARDED
# 3              120000.0             0.0              NO SHOW
# 4              120000.0             0.0              NO SHOW
# ...                 ...             ...                  ...
# 171162         567040.0             0.0               ACTIVE
# 171163         567040.0             0.0               ACTIVE
# 171164         567040.0             0.0               ACTIVE
# 171165         567040.0             0.0               ACTIVE
# 171166         567040.0             0.0               ACTIVE
#
#        has_boarding_pass is_revenue  ptc  crs_code  travel_agent_booking  \
# 0                    YES         NO  ADT       NaN                   YES
# 1                    YES         NO  ADT       NaN                   YES
# 2                    YES         NO  ADT       NaN                   YES
# 3                     NO         NO  ADT       NaN                   YES
# 4                     NO         NO  ADT       NaN                   YES
# ...                  ...        ...  ...       ...                   ...
# 171162                NO        YES  ADT       NaN                   YES
# 171163                NO        YES  ADT       NaN                   YES
# 171164                NO        YES  ADT       NaN                   YES
# 171165                NO        YES  ADT       NaN                   YES
# 171166                NO        YES  ADT       NaN                   YES
#
#         iata_num  convert_timezone
# 0       37300005               NaN
# 1       37300005               NaN
# 2       37300008               NaN
# 3       37300005               NaN
# 4       37300005               NaN
# ...          ...               ...
# 171162  37100300               NaN
# 171163  37100300               NaN
# 171164  37100300               NaN
# 171165  37100300               NaN
# 171166  37100300               NaN
#
# [171167 rows x 29 columns]
